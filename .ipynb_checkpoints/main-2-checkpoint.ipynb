# %% [markdown]
# # Track the International Space Station

# %% [markdown]
# ##### Import Modules

# %%
import requests
import json
import time
import plotly.express as px

# %% [markdown]
# ##### Function to write to file

# %%
def file_io(mode,json_data,f_name):
    if mode == 'a+' or mode == 'w':
        with open(f_name,mode) as f_handler:
            json.dump(json_data,f_handler)
            f_handler.write("\n")
    elif mode == 'r' :
        with open(f_name,mode) as f_handler:
            f_content = f_handler.readlines()
            return f_content

# %% [markdown]
# ##### Function to make a call to ISS open-API

# %%
def get_iss_info(write_optn='n',t_interval=1,t_total=1):
    print("Total number of data points: {}".format(int(t_total/t_interval)))
    f_name = 'iss_data'
    t_counter = 0
    t_now = 1
    info_lst = []
    while t_now <= t_total:
        iss_data = requests.get('http://api.open-notify.org/iss-now.json').json()
        t_now += t_interval
        t_counter += 1
        if write_optn == 'y':
            mode = 'a+'
            file_io(mode,iss_data,f_name)
        else :
            print(iss_data)
        time.sleep(t_interval)
    return 0

# %% [markdown]
# ##### Main

# %%
#a=get_iss_info('n',30,3600)

f_content = file_io('r','m','iss_data')

iss_data_lst = []
lat_lst = []
lon_lst = []
time_lst = []

for line in f_content:
    iss_data_lst.append(json.loads(line.strip()))

time_zero = iss_data_lst[0]['timestamp']

for element in iss_data_lst:
    lat_lst.append(element['iss_position']['latitude'])
    lon_lst.append(element['iss_position']['longitude'])
    time_lst.append((element['timestamp']-time_zero)/60)
print("Data collection complete.")

projection_mode = 'orthographic'
fig = go.Figure(px.scatter_geo(lat=lat_lst,lon=lon_lst,projection=projection_mode,
                               opacity=0.5,hover_name=time_lst))
fig.update_layout(width=850, margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
fig = go.Figure(px.scatter_geo(lat=lat_lst,lon=lon_lst,
                               opacity=0.5,hover_name=time_lst))
fig.update_layout(width=850, margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# Data collection complete.
# <div>                            <div id="9e4273b3-15a1-4966-bc03-f5fc997e924a" class="plotly-graph-div" style="height:525px; width:850px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e4273b3-15a1-4966-bc03-f5fc997e924a")) {                    Plotly.newPlot(                        "9e4273b3-15a1-4966-bc03-f5fc997e924a",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":[0.0,0.5,1.0,1.5,2.0166666666666666,2.5166666666666666,3.0166666666666666,3.533333333333333,4.033333333333333,4.533333333333333,5.033333333333333,5.533333333333333,6.033333333333333,6.55,7.05,7.55,8.05,8.566666666666666,9.066666666666666,9.566666666666666,10.066666666666666,10.566666666666666,11.066666666666666,11.583333333333334,12.083333333333334,12.583333333333334,13.1,13.6,14.1,14.6,15.116666666666667,15.616666666666667,16.116666666666667,16.616666666666667,17.116666666666667,17.616666666666667,18.133333333333333,18.633333333333333,19.15,19.65,20.15,20.65,21.15,21.666666666666668,22.166666666666668,22.666666666666668,23.166666666666668,23.683333333333334,24.183333333333334,24.683333333333334,25.183333333333334,25.7,26.2,26.7,27.2,27.716666666666665,28.216666666666665,28.716666666666665,29.216666666666665,29.733333333333334,30.233333333333334,30.733333333333334,31.25,31.75,32.25,32.75,33.266666666666666,33.766666666666666,34.266666666666666,34.78333333333333,35.28333333333333,35.78333333333333,36.28333333333333,36.78333333333333